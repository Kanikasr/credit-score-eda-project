# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanikasr/credit-score-eda-project/blob/main/credit_score_risk_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Credit Score Risk Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Kanika Singh Rajpoot

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on performing a comprehensive Exploratory Data Analysis (EDA) for credit score classification based on customer demographics, financial behavior, and loan history. The objective is to uncover meaningful patterns that influence credit scores, enabling better decision-making for credit risk evaluation and personalized financial product offerings by Paisabazaar.
#
# **Data Overview**
# The dataset includes diverse features such as:
#
# *Demographic attributes:* Age, Occupation, Monthly Salary
#
# *Financial indicators:* Annual Income, Credit Card Usage, Credit Inquiries
#
# *Loan behavior:* Types of loans, Delays in payment, Outstanding debt
#
# *Derived metrics:* Credit Utilization Ratio, Credit History Age, Monthly Balance
#
# The target variable, credit_score, is categorized into Poor, Standard, and Good, representing customer creditworthiness.
#
# **Univariate Analysis:**
# We began with understanding the distribution of individual variables. *Age* and *credit history* showed concentration in younger demographics with moderate credit age. The *credit score* category distribution was imbalanced, with a higher share of standard and poor scores, indicating a moderate-to-high-risk customer base. Features like *annual income* and *credit utilization ratio* showed right-skewed distributions, prompting transformations.
#
# **Bivariate Analysis:**
# We explored the relationships between credit scores and key financial indicators:
#
# *Credit Score vs Age*: Younger customers tended to fall into the poor credit category, while older customers showed a higher tendency toward good scores.
#
# *Occupation*: Salaried and managerial roles were associated with better credit profiles, while occupations like Mechanic and Writer showed higher risk.
#
# *Annual Income & Inquiries*: Lower income and frequent credit inquiries were more common among poor score holders.
#
# *Delay from Due Date*: Poor credit scores had a higher median delay and wider variation in late payments, clearly signaling poor repayment behavior.
#
#
# **Multivariate Analysis:**
# To understand interactions among multiple features:
#
# A *correlation heatmap* revealed strong links between variables like EMI, outstanding debt, credit inquiries, and monthly balance. This guided feature selection for modeling.
#
# The *pair plot* helped visualize class clustering and separation between good and poor credit holders.
#
# A *bubble plot* (EMI vs Investment vs Income) demonstrated how customers with higher income and investments tend to have fewer inquiries and better scores.
#
# A *KDE plot* of monthly salary across credit scores showed that higher in-hand salary distribution skews towards good scores.
#
# **We also studied:**
#
# *Credit Score vs Payment Behaviour*: Risky or irregular payers were overwhelmingly poor scorers.
#
# *Credit Cards vs Utilization Ratio*: Over-utilization correlated with poor credit, regardless of card count.
#
# *Monthly Balance vs Age*: Good scorers showed increasing savings with age; poor scorers remained financially strained across age bins.
#
# **Business Value & Recommendations:**
# The insights from EDA provide immense value to Paisabazaar:
#
# *Risk profiling*: Understanding which combinations of income, payment behavior, and loan types lead to poor scores helps target high-risk segments with stricter screening.
#
# *Product personalization*: Customers with moderate scores can be steered toward better financial behavior via customized loan products and repayment plans.
#
# *Predictive modeling*: The patterns and relationships uncovered will improve the performance of credit score classification models by providing the right set of engineered features.
#
# **Conclusion:**
# This EDA project successfully revealed the financial and behavioral factors that influence credit scores. The insights derived can guide actionable strategies to reduce risk, enhance financial literacy, and optimize product targeting. By aligning data understanding with business goals, Paisabazaar can make smarter lending decisions and build stronger customer relationships.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# 🔗 GitHub Link: [My Project Repo](https://github.com/Kanikasr/credit-score-eda-project)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The goal of this project is to analyze and classify customers based on their credit scores using financial, behavioral, and demographic data. By understanding patterns that differentiate good, standard, and poor credit holders, Paisabazaar aims to:
#
# Improve credit risk assessment and lending decisions
#
# Enable personalized financial recommendations
#
# Support targeted interventions for high-risk customers
#
# Lay the foundation for predictive credit score classification models
#
# Ultimately, the objective is to drive smarter credit strategies that reduce defaults and enhance customer trust.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# from google.colab import drive
# drive.mount('/content/drive')
file_path = '/content/drive/My Drive/capstone_project_2/dataset.csv'
data = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = data.duplicated().sum()
print(f"Total duplicate rows: {duplicate_count}")
# Out:
# Total duplicate rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Count total missing values per column
missing_values = data.isnull().sum()

# Filter only columns with missing values
missing_values = missing_values[missing_values > 0]

# Display missing values
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Series([], dtype: int64)

# %%
# Visualizing the missing values
# Plot missing value count per column
# plt.figure(figsize=(10,6))
# sns.barplot(x=missing_values.values, y=missing_values.index, palette='Reds_r')
# plt.title('Missing Values per Column')
# plt.xlabel('Count of Missing Values')
# plt.ylabel('Column')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The credit score raw dataset has 100000 rows and 28 columns with mainly 3 datatypes int,float,object. By basic coding it seems the dataset doesnt have any missing values and null values though after further inspection they might be in some other format but as of now it shows 0 values and so the plot also shows blank because there are 0 count. If dataset had missing values the given plot would have worked, so it can be used for visualizing the number of missing values. There are no duplicate values too. 28 columns each show different aspects of credit score data which can be useful for general analysis but some might be redundant for general purpose they might be useful for individual data visualization example:Name,SSN.The dataset has imporatnt columns which will help us to analyze their relationships essential for framing the credit score prediction in future for our problem statement.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(data.columns.tolist())
# Out:
# ['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance', 'Credit_Score']

# %%
# Dataset Describe (numerical columns only)
print(data.describe())
#Include all columns (even non-numerical)
# print(df.describe(include='all'))
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains various attributes related to customer financial behavior and credit score classification. The **ID** and **Customer_ID** are unique identifiers for each data entry and customer, respectively. The **Month** field indicates the calendar month (in numeric form) when the data was recorded. **Name** captures the full name of the customer, while **Age** is their age in years. **SSN** refers to the customer's Social Security Number, used for identification.
#
# The **Occupation** column specifies the customer's professional background, such as Engineer, Teacher, etc. **Annual_Income** represents the customer’s yearly income in local currency, and **Monthly_Inhand_Salary** indicates their net salary available per month after deductions. **Num_Bank_Accounts** shows how many bank accounts the customer holds, and **Num_Credit_Card** refers to the number of credit cards they own. The **Interest_Rate column** gives the average interest rate on the customer’s active credit lines.
#
# **Num_of_Loan** indicates how many loans the customer has taken. **Type_of_Loan** lists different loan types the customer holds, which may include personal loans, auto loans, etc., often in a delimited format. **Delay_from_due_date** measures how many days the customer paid after the due date. **Num_of_Delayed_Payment** aggregates how many times the customer has made delayed payments historically. **Changed_Credit_Limit** captures any change in the customer's credit limit over time.
#
# The **Num_Credit_Inquiries** reflects how many times the customer’s credit report was accessed for new applications. **Credit_Mix** categorizes the diversity of credit types held (e.g., Good, Bad, Standard). **Outstanding_Debt** shows the remaining amount of debt to be repaid, while **Credit_Utilization_Ratio** measures the percentage of available credit currently being used. **Credit_History_Age** represents the total age of credit history, typically in years and months.
#
# **Payment_of_Min_Amount** shows whether the customer has been paying at least the minimum due amount. **Total_EMI_per_month** gives the total EMI (Equated Monthly Installment) amount paid monthly across all loans. **Amount_invested_monthly** reflects how much the customer invests every month. **Payment_Behaviour** describes patterns of payment, such as early or minimum payments. **Monthly_Balance** is the remaining monthly balance after all expenses, EMIs, and investments.
#
# Finally, **Credit_Score** is the target variable, classifying customers into categories such as Good, Standard, or Poor based on their overall credit behavior.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable. Counting unique values per column
unique_counts = data.nunique()
print(unique_counts)
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10128
# Age                             43
# SSN                          12500
# Occupation                      15
# Annual_Income                12488
# Monthly_Inhand_Salary        13241
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Interest_Rate                   34
# Num_of_Loan                     10
# Type_of_Loan                  6261
# Delay_from_due_date             63
# Num_of_Delayed_Payment          26
# Changed_Credit_Limit          3452
# Num_Credit_Inquiries            18
# Credit_Mix                       3
# Outstanding_Debt             12203
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          11890
# Amount_invested_monthly      12261
# Payment_Behaviour                6
# Monthly_Balance              98494
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Step 0: Copy original DataFrame
df_cleaned = data.copy()

# Step 1: Drop identifier columns
columns_to_drop = ['ID', 'Customer_ID', 'Name', 'SSN']
df_cleaned.drop(columns=columns_to_drop, inplace=True)

# Step 2: Replace placeholders with np.nan
missing_values = ['No Data', 'NA', 'Unknown', 'N/A', '--', '', ' ','-']
df_cleaned.replace(missing_values, np.nan, inplace=True)

# Step 3: Standardize column names
df_cleaned.columns = (
    df_cleaned.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('-', '_')
    .str.replace(r'[^0-9a-zA-Z_]', '', regex=True)
)

# Step 4: Convert categorical columns to category dtype
categorical_columns = [
    'occupation', 'type_of_loan', 'credit_mix',
    'payment_of_min_amount', 'payment_behaviour', 'credit_score'
]
df_cleaned[categorical_columns] = df_cleaned[categorical_columns].astype('category')

# Step 5: Convert integer-like columns
int_columns = [
    'num_bank_accounts', 'num_credit_card', 'interest_rate',
    'num_of_loan', 'delay_from_due_date', 'num_of_delayed_payment',
    'num_credit_inquiries', 'credit_history_age'
]
df_cleaned[int_columns] = df_cleaned[int_columns].round().astype('Int64')

# Step 6: Log-transform skewed numeric columns
skewed_cols = ['annual_income', 'outstanding_debt', 'amount_invested_monthly', 'monthly_balance']
for col in skewed_cols:
    df_cleaned[f'log_{col}'] = np.log1p(df_cleaned[col])

# Step 7: Clean 'type_of_loan' and create binary features
df_cleaned['type_of_loan'] = df_cleaned['type_of_loan'].astype(str).str.lower().fillna('')
df_cleaned['type_of_loan'] = df_cleaned['type_of_loan'].str.replace(r'\s+and\s+', ',', regex=True)
placeholders = ['not specified', 'no data', 'nan', 'unknown']
for ph in placeholders:
    df_cleaned['type_of_loan'] = df_cleaned['type_of_loan'].str.replace(ph, '', regex=False)
df_cleaned['type_of_loan'] = df_cleaned['type_of_loan'].str.replace(r',+', ',', regex=True)
df_cleaned['type_of_loan'] = df_cleaned['type_of_loan'].str.strip(',').str.strip()
df_cleaned['type_of_loan_list'] = df_cleaned['type_of_loan'].apply(
    lambda x: list(set([loan.strip().title() for loan in x.split(',') if loan.strip()]))
)
unique_loans = set(loan for sublist in df_cleaned['type_of_loan_list'] for loan in sublist)
for loan in unique_loans:
    df_cleaned[f'loan_{loan.lower().replace(" ", "_")}'] = df_cleaned['type_of_loan_list'].apply(
        lambda x: 1 if loan in x else 0
    )
df_cleaned.drop(columns=['type_of_loan_list', 'type_of_loan'], inplace=True)

# Step 8: Convert 'payment_of_min_amount' to binary
df_cleaned['payment_of_min_amount'] = df_cleaned['payment_of_min_amount'].astype(str).str.strip().str.lower()
df_cleaned['payment_min_binary'] = df_cleaned['payment_of_min_amount'].map({
    'yes': 1,
    'no': 0,
    'nm': np.nan
})

# Step 9: Detect and flag outliers
numeric_cols = [
    'annual_income', 'monthly_balance', 'outstanding_debt',
    'credit_utilization_ratio', 'amount_invested_monthly', 'total_emi_per_month'
]

def detect_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (df[col] < lower_bound) | (df[col] > upper_bound)

for col in numeric_cols:
    df_cleaned[f'{col}_outlier'] = detect_outliers_iqr(df_cleaned, col)

# Step 10: Outlier treatment
# (1) Log-transform for skewed columns (again for safety)
log_transform_cols = ['annual_income', 'outstanding_debt', 'monthly_balance']
for col in log_transform_cols:
    df_cleaned[f'log_{col}'] = np.log1p(df_cleaned[col])

# (2) Capping (Winsorization)
def cap_outliers(df, col, lower_percentile=0.01, upper_percentile=0.99):
    lower_bound = df[col].quantile(lower_percentile)
    upper_bound = df[col].quantile(upper_percentile)
    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])
    return df

cap_only_cols = ['num_credit_inquiries', 'delay_from_due_date', 'changed_credit_limit']
for col in cap_only_cols:
    df_cleaned = cap_outliers(df_cleaned, col)

# (3) Combination: capping + log for important columns
cap_and_log_cols = ['total_emi_per_month', 'amount_invested_monthly']
for col in cap_and_log_cols:
    df_cleaned = cap_outliers(df_cleaned, col)
    df_cleaned[f'log_{col}'] = np.log1p(df_cleaned[col])

# Final column name formatting
df_cleaned.columns = df_cleaned.columns.str.replace('-', '_')

# Save cleaned data
# df_cleaned.to_csv('cleaned_credit_data.csv', index=False)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# To begin the data preparation process, we created a copy of the original dataset to ensure that our cleaning operations did not alter the raw data. We then removed identifier columns such as **ID, Customer_ID, Name, and SSN,** as these fields do not contribute any analytical or predictive value and may pose privacy concerns. Next, we standardized missing values by replacing common placeholders like **'No Data', 'NA', 'Unknown', and blanks with np.nan**, enabling consistent handling of missing entries. We also standardized column names by converting them to **lowercase, replacing spaces and special characters** with underscores to make the dataset cleaner and more manageable in code.
#
# To optimize memory usage and prepare for categorical analysis, we explicitly converted categorical columns such as **occupation, type_of_loan, credit_mix, payment_of_min_amount, payment_behaviour, and credit_score to the category data** type. Numeric columns that represented counts or discrete values, such as the **number of credit cards or credit inquiries, were rounded and converted to integer format** to better reflect their actual meaning and to eliminate unnecessary decimal values.
#
# Since several **numeric columns were highly skewed (e.g., annual_income, outstanding_debt, amount_invested_monthly, and monthly_balance), we applied logarithmic transformation (log1p)** to reduce skewness and stabilize variance, making them more suitable for visualizations and modeling. For the **type_of_loan column, which included multiple loan types in a single string, we cleaned and split the values into individual categories, creating binary columns** for each loan type to enable multi-label analysis.
#
# The **payment_of_min_amount column**, which originally contained categorical responses such as 'Yes', 'No', and 'NM', was mapped to a binary format to simplify interpretation. We also detected outliers in key **numeric columns using the interquartile range (IQR) method and flagged them** accordingly. For certain columns with extreme values, such as **num_credit_inquiries and delay_from_due_date, we applied capping (Winsorization)** to limit their range without removing data. For **heavily skewed and important columns like total_emi_per_month and amount_invested_monthly, we used a combination of capping and log transformation** to bring them within a manageable range.
#
# Finally, we saved the fully cleaned and transformed dataset to a new CSV file (cleaned_credit_data.csv) for use in subsequent exploratory data analysis and modeling. This comprehensive preprocessing ensured the data was clean, consistent, and analytically robust.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
df = pd.read_csv('/content/drive/My Drive/capstone_project_2/cleaned_credit_data.csv')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# #### Chart - 1 Distribution of Age (Histogram), Numeric (single variable)

# %%
# Chart - 1 visualization code
# Set plot style
sns.set(style="whitegrid")

# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], kde=True, bins=30, color='skyblue')

# Add title and labels
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is ideal for visualizing the distribution of a single continuous variable. Since we are analyzing age, which is numerical and continuous, a histogram helps us:
#
# -Understand the spread, central tendency, and skewness of customer age.
#
# -Identify any dominant age groups or unusual gaps/outliers in the age range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this histogram:
#
# The most frequent age group is likely between 24 and 48 years, showing peaks.
#
# There is a relatively normal distribution, but potentially with a slight right/positive skew, suggesting more customers in the younger to middle age range.
#
# Very few customers are above 50 or below 20.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. gained insights help creating a positive business impact as:
#
# -Knowing the dominant age segment helps the company tailor marketing, product offerings, and credit strategies toward those age groups.
#
# -For example, if most users are 28–45, products like home loans or investment options might be promoted more.
#
# -It can also guide risk management—younger individuals may behave differently in terms of credit risk than older individuals.
#
# No insight directly lead to negative growth. But:
#
# If the business is missing key age demographics, like people over 60 (e.g., retired individuals), they might be losing out on niche credit products (like reverse mortgages or senior investment plans).
#
# An age gap could indicate untapped markets or biased product outreach.

# %% [markdown]
# #### Chart - 2 Distribution of Credit Score Categories (Pie Chart), Categorical

# %%
# Count values for each credit score category
score_counts = df['credit_score'].value_counts()

# Define color mapping (consistent with your Tableau theme)
custom_colors = {
    'Good': sns.color_palette("Greens")[2],      # Soft green
    'Standard': sns.color_palette("Blues")[3],   # Medium blue
    'Poor': sns.color_palette("Reds")[3]         # Medium red
}

color_list = [custom_colors[label] for label in score_counts.index]

# Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(score_counts,
        labels=score_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=color_list,
        textprops={'fontsize': 12})

plt.title('Credit Score Distribution', fontsize=14)
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pie chart is the most effective for visualizing the distribution of a categorical variable like credit_score. It instantly shows the proportion of records in each category and helps in understanding customer segmentation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution shows that more than half the customers fall into the "Standard" credit score category. This implies a large portion of users are neither at financial risk nor ideal borrowers, suggesting a potential opportunity for credit improvement services. The remaining users are skewed toward Poor, followed by a smaller group with Good scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. By identifying that most users are "Standard", the business can design targeted credit-building programs or education to uplift them to "Good", potentially expanding the qualified customer base for loans, cards, and offers. Likewise, the "Poor" segment can be targeted with risk-mitigating financial products or interventions.
#
# Yes. The high number of "Poor" credit score customers (nearly 29%) could indicate elevated risk levels in the customer base, which might lead to higher default rates if not monitored or assisted. Additionally, the low share of "Good" scores may imply under-penetration of premium credit products.

# %% [markdown]
# #### Chart - 3  Distribution of Occupation (Count Plot), Categorical

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12, 6))
ax = sns.countplot(
    data=df,
    x='occupation',
    order=df['occupation'].value_counts().index,
    hue='occupation',
    palette='Set3',
    legend=False
)

# Add count labels on top of bars
for p in ax.patches:
    count = int(p.get_height())
    ax.annotate(f'{count}', (p.get_x() + p.get_width() / 2, count),
                ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.title('Distribution of Occupation')
plt.xlabel('Occupation')
plt.ylabel('Number of Records')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is the most direct way to visualize how many individuals fall into each occupation category. It provides a clear overview of occupational representation in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some occupations like Lawyer, Engineer, and Architect appear much more frequently compared to others like Writer or Musician. This suggests certain job types are overrepresented in this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Identifying the dominant occupations can help tailor financial products, credit score guidelines, or risk assessment models specifically for those segments.
#
# If underrepresented occupations like Writer or Architect are overlooked, financial institutions might fail to design inclusive services or credit scoring models that serve niche but growing demographics. This can lead to missed growth opportunities.

# %% [markdown]
# #### Chart - 4 Distribution of Annual Income (Histogram), Numeric

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='annual_income', kde=True, bins=30, color='skyblue')
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is suitable to observe the distribution and skewness of continuous variables like annual income. Adding a KDE curve helps visualize the density pattern.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The annual income distribution is right-skewed, indicating most individuals earn on the lower end of the income range, while a smaller group has very high incomes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Businesses can use this to segment low and high-income customers differently—for credit approval strategies, loan products, or interest rate offers.
#
# If products are designed assuming uniform income distribution, high-income outliers might disproportionately affect the average, potentially leading to misjudgment in customer affordability metrics.

# %% [markdown]
# #### Chart - 5. Distribution of Credit History Age (Histogram), Numeric

# %%
# Chart - 5 visualization code
# Convert credit history from months to years
df['credit_history_years'] = df['credit_history_age'] / 12

# Plotting histogram
plt.figure(figsize=(8, 5))
sns.histplot(df['credit_history_years'], kde=True, bins=30, color='mediumseagreen')
plt.title('Distribution of Credit History Age')
plt.xlabel('Credit History Age (in years)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We use a histogram to observe the frequency distribution of a continuous numerical variable like credit history age. It helps identify how long most customers have had credit history, which is crucial for creditworthiness.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers have a credit history between 6 to 32 years.
#
# The highest concentration is observed in the 16–20 year range, indicating a mature borrower base.
#
# The distribution is slightly right-skewed, with a gradual drop-off after 32 years.
#
# There are very few customers with less than 5 years or more than 35 years of credit history.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A strong concentration in the 16–20 year range indicates that many customers have established financial behavior, which reduces lending risk and improves model reliability.
#
# The lower density of users below 5 years suggests fewer new-to-credit customers, which may limit long-term customer growth unless specific onboarding strategies are implemented.

# %% [markdown]
# #### Chart - 6 Count of Each Type of Loan (Bar plot), Categorical (binary loan types counted)

# %%
# Identify loan-related columns
loan_cols = [col for col in df.columns if col.startswith('loan_')]

# Calculate total count for each loan type
loan_totals = df[loan_cols].sum().sort_values(ascending=False)

# Prepare loan type labels (clean names)
loan_labels = loan_totals.index.str.replace('loan_', '').str.replace('_loan', '').str.replace('_', ' ').str.title()

# Create a DataFrame for plotting to allow using hue
loan_df = pd.DataFrame({
    'Loan Type': loan_labels,
    'Total Count': loan_totals.values
})

# Plot
plt.figure(figsize=(12, 6))
bars = sns.barplot(data=loan_df, x='Loan Type', y='Total Count', hue='Loan Type', palette='Blues_d', dodge=False, legend=False)

plt.title('Total Count of Each Type of Loan')
plt.xlabel('Loan Type')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')

# Add labels on top of bars
for bar in bars.patches:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 200,
             f'{int(height)}',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is well-suited for comparing discrete categories like loan types. It helps visualize which types of loans are most common among customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Payday loans and Credit builder loans have the highest number of customers.
#
# Auto loans and Student loans are also common, suggesting diverse borrowing purposes.
#
# Home equity and Mortgage loans are relatively less common, indicating fewer high-value asset-backed loans.
#
# A significant number of customers have multiple loan types, reflecting financial dependency on various products.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding which loan types are most popular can help financial institutions target marketing, improve offerings, and create bundled financial products to meet demand.
#
# The dominance of Payday loans, which are often high-risk with high interest, may signal potential financial stress among borrowers. This could lead to higher default risk, affecting profit margins unless managed with stricter risk controls.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# #### Chart - 7 Credit Score vs Avg utilization (Bar plot),  Category (credit_score) vs Numeric (avg utilization)

# %%
avg_utilization = df.groupby('credit_score')['credit_utilization_ratio'].mean().reset_index()
color_map = {'Good': 'green', 'Poor': 'red', 'Standard': 'blue'}

plt.figure(figsize=(8,6))
barplot = sns.barplot(
    data=avg_utilization,
    x='credit_score',
    y='credit_utilization_ratio',
    hue='credit_score',
    palette=color_map,
    dodge=False
)

# Safely remove legend if it exists
if barplot.legend_ is not None:
    barplot.legend_.remove()

# Add labels on top of bars
for p in barplot.patches:
    height = p.get_height()
    barplot.annotate(f'{height:.2f}',
                     (p.get_x() + p.get_width() / 2, height),
                     ha='center', va='bottom',
                     fontsize=11,
                     color='black',
                     xytext=(0, 5),
                     textcoords='offset points')

plt.xlabel('Credit Score')
plt.ylabel('Average Credit Utilization Ratio (%)')
plt.title('Average Credit Utilization Ratio by Credit Score')
plt.tight_layout()
plt.show()


# Group and show the data used in the plot
avg_utilization = df.groupby('credit_score')['credit_utilization_ratio'].mean().reset_index()
print(avg_utilization)
# Out:
#   credit_score  credit_utilization_ratio
# 0         Good                 32.686107
# 1         Poor                 31.986146
# 2     Standard                 32.313820

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar plot to show the average credit utilization ratio by credit score because:
#
# It clearly summarizes and compares the mean utilization across discrete credit score categories (Good, Poor, Standard).
#
# Bar plots make it easy to visualize and communicate differences between groups at a glance.
#
# It’s a simple, interpretable visualization perfect for comparing aggregate statistics, which helps stakeholders quickly understand trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average credit utilization ratio is very similar across all credit score categories, hovering around ~32%.
#
# Contrary to typical expectations, poor credit score customers do not have significantly higher average utilization than good or standard score groups.
#
# This could imply that credit utilization alone may not be the strongest differentiator between credit score categories in the dataset or that other factors (like payment behavior, loan types, etc.) may be more influential.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, because:**
#
# Understanding that credit utilization is roughly consistent across credit score groups helps the credit risk team avoid overemphasizing utilization alone when assessing risk.
#
# This encourages a more holistic approach to credit scoring, including payment history, loan types, and other financial behaviors.
#
# It can inform better targeting of credit products or risk mitigation strategies by focusing on more predictive factors.
#
# **Potential concern:**
#
# Since credit utilization is not markedly different among credit score groups, relying heavily on this metric could mislead lending decisions, possibly increasing risk exposure if other risk factors are ignored.
#
# If the business had a policy of restricting credit to those with high utilization, this data suggests that approach might unfairly penalize customers with good credit scores, affecting customer satisfaction and retention.
#
# This calls for revisiting credit risk models to avoid negative impacts from over-reliance on utilization metrics.

# %% [markdown]
# #### Chart - 8 Credit Score vs Age(Box Plot), Category (credit_score) vs Numeric (Age)

# %%
custom_palette = {
    'Good': '#a8ddb5',      # Light green
    'Standard': '#9ecae1',  # Light blue
    'Poor': '#fcae91'       # Light red
}
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='credit_score', y='age', hue='credit_score', palette=custom_palette, legend=False)
plt.title('Age Distribution by Credit Score Category')
plt.xlabel('Credit Score Category')
plt.ylabel('Age')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is chosen to understand the distribution of age across each credit score category and to detect outliers, medians, and variability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The median age is highest in the Good credit score group, moderate in the Standard group, and lowest in the Poor group.
#
# All three groups have similarly shaped box plots, indicating comparable age variability.
#
# There are outliers in each group, especially among younger individuals with poor scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This indicates that creditworthiness improves with age, possibly due to more stable income, longer credit history, and better financial discipline. This can help in designing age-targeted credit offerings.
#
# A significant concentration of younger individuals in the poor credit segment may suggest risky lending behavior in that age group. This could lead to increased defaults if not addressed by stricter eligibility checks or financial literacy programs.

# %% [markdown]
# #### Chart - 9 Credit Score vs Occupation(Stacked Bar Plot), Category vs Category

# %%
# Chart - 9 visualization code
# Group by occupation and credit_score to count records
occupation_score = df.groupby(['occupation', 'credit_score']).size().reset_index(name='Count')

# Pivot to wide format for stacking
occupation_score_pivot = occupation_score.pivot(index='occupation', columns='credit_score', values='Count').fillna(0)

# Reorder columns for visual consistency
credit_order = ['Standard', 'Poor', 'Good']
occupation_score_pivot = occupation_score_pivot[credit_order]

# Normalize rows to get percentage distribution
occupation_score_pct = occupation_score_pivot.div(occupation_score_pivot.sum(axis=1), axis=0)

# Sort occupations by proportion of Good credit score
occupation_score_pct = occupation_score_pct.sort_values(by='Good', ascending=False)

# Plot
ax = occupation_score_pct.plot(
    kind='bar', stacked=True, figsize=(14, 7), colormap='Set2', legend=True
)
plt.title('Proportion of Credit Scores by Occupation')
plt.ylabel('Proportion (0 to 1)')
plt.xlabel('Occupation')
plt.xticks(rotation=45)
plt.legend(title='Credit Score')

# Annotate percentage labels on bars
for i, col in enumerate(occupation_score_pct.columns):
    for j, (idx, val) in enumerate(occupation_score_pct[col].items()):
        cumulative = occupation_score_pct.iloc[j, :i].sum()
        if val > 0.03:  # Avoid clutter for small segments
            ax.text(j, cumulative + val / 2, f"{val:.2f}", ha='center', va='center', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps visualize how credit scores are distributed across different occupations, enabling a clear comparison of financial behavior among job groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Occupations like Journalist, Musician, Media_Manager, Manager might show a higher proportion of good credit scores(0.19).
#
# Others like Writer(0.14) and Mechanic(0.16) groups may show lowest good credit score ratios.
#
# Certain job roles like Architect, Developer, Scientist maintain a balanced distribution, indicating stable but varied financial practices.
#
# Occupations with mostly poor scores may need financial support schemes or focused risk evaluation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Lenders can customize credit offerings based on occupation-linked credit behavior. Occupations with good scores are low-risk and can be offered premium products, while those with poor scores may receive credit education or secured products.
#
# A segment of employed individuals with poor scores can indicate hidden financial distress, over-dependence on credit, or poor financial planning, affecting repayment capacity.

# %% [markdown]
# #### Chart 10 Credit Score vs Annual Income (Log) — Box Plot, Category vs Numeric

# %%
# Chart - 10 visualization code
custom_palette = {
    'Good': '#a8ddb5',      # Light green
    'Standard': '#9ecae1',  # Light blue
    'Poor': '#fcae91'       # Light red
}
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='credit_score', y='log_annual_income', hue='credit_score',
            order=['Poor','Standard',  'Good'], palette=custom_palette, legend=False)
plt.title('Credit Score vs Log Annual Income')
plt.xlabel('Credit Score Category')
plt.ylabel('Log Annual Income')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is ideal for comparing the distribution, spread, and central tendency (median) of log_annual_income across different credit_score categories. Since income can vary drastically and may be skewed, the log transformation helps compress outliers and reveal meaningful differences more clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The median income is highest for the Good credit score category, though it's positioned towards the lower half of the box, indicating a slight left skew.
#
# Standard credit score holders have a median income that is slightly higher than Poor, and both their medians are near the center of the box.
#
# The spread (IQR) or box size is fairly similar across all categories, suggesting income variability is consistent regardless of credit score category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows that higher income is moderately associated with better credit scores. Financial institutions can use this to refine their credit risk models and marketing segmentation — targeting higher-income groups for premium credit products or lower risk loans.
#
# Not directly, but it’s important to note that:
# -Even people with moderate or low income can fall into the Good category, meaning income alone isn’t a perfect predictor of creditworthiness.
# -Relying too heavily on income might lead to missing out on responsible borrowers in lower-income brackets, which can limit market reach and result in missed growth opportunities.

# %% [markdown]
# #### Chart 11 Credit Score vs Number of Credit Inquiries (Box Plot), Category vs Numeric

# %%
# Chart - 11 visualization code
custom_palette = {
    'Good': '#a8ddb5',      # Light green
    'Standard': '#9ecae1',  # Light blue
    'Poor': '#fcae91'       # Light red
}
plt.figure(figsize=(10,6))
sns.boxplot(x='credit_score', y='num_credit_inquiries', data=df,
            order=['Standard','Poor','Good'], palette=custom_palette, hue='credit_score', legend=False)
plt.title('Credit Score vs Number of Credit Inquiries')
plt.xlabel('Credit Score Category')
plt.ylabel('Number of Credit Inquiries')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is appropriate for comparing how the number of credit inquiries varies across credit score categories. It shows distribution, median, and outliers, allowing for clear visual comparison of credit-seeking behavior between groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Lower Inquiries Are Linked with Better Credit Scores
# Good credit score users tend to have fewer credit inquiries.
# This suggests they are less likely to seek frequent credit, a behavior favored by credit scoring models.
# 2. Higher Inquiries Are Associated with Poor Credit Scores
# Poor credit score users show more credit inquiries, as seen by a higher median and larger spread.
# This may signal credit-hungry behavior, financial stress, or frequent loan rejections.
# 3. Standard Score Is in the Middle—but Varies Widely
# The Standard group shows moderate inquiry behavior, with a wider distribution.
# This category includes a mix of users: some stable, some drifting toward risk.
# 4. Outliers Are Mostly in the Good Score Category
# Despite low typical inquiries, some Good score users have high inquiry outliers.
# These may be rate shoppers (e.g., for home/car loans), not necessarily risky customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This analysis shows a strong relationship between frequent credit inquiries and lower credit scores. Lenders can use this to:
# -Flag high inquiry frequency as a risk factor in credit scoring.
# -Offer pre-screened, low-risk credit options to individuals with fewer inquiries.
#
# Yes, if misinterpreted. Over-penalizing users with multiple inquiries may hurt:
# -Young borrowers or rate-shoppers who compare offers.
# -Credit-savvy users with strategic inquiry patterns.
# This could lead to lost opportunities in acquiring potentially reliable borrowers who simply explored their options.

# %% [markdown]
# #### Chart 12 Credit Score vs Delay from Due Date (Box Plot), Category vs Numeric

# %%
# Chart - 12 visualization code
custom_palette = {
    'Good': '#a8ddb5',      # Light green
    'Standard': '#9ecae1',  # Light blue
    'Poor': '#fcae91'       # Light red
}
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='credit_score', y='delay_from_due_date', hue='credit_score', palette=custom_palette, legend=False)
plt.title('Credit Score vs Delay from Due Date')
plt.xlabel('Credit Score')
plt.ylabel('Delay from Due Date (in days)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is ideal for comparing the distribution, central tendency, and variability of delay in repayments across credit score categories. It reveals outliers and skewness, helping us identify payment discipline patterns linked to creditworthiness.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Strong correlation between delay patterns and credit score:
# As credit score improves from Poor to Standard to Good, the median delay decreases, and variability becomes tighter, reflecting better repayment discipline.
#
# Poor credit scorers show high-risk behavior:
# The high median delay and wide spread indicate frequent and inconsistent late payments, making them a financially unstable group.
# Such borrowers may require stricter lending criteria, collateral, or financial counseling.
#
# Standard scorers represent a transition zone:
# This group exhibits moderate payment delays and mixed repayment behavior.
# They can be targeted with improvement programs or monitored more closely for early signs of deterioration or potential upgrade.
#
# Good scorers are the most disciplined:
# Low delays and tight box size show consistent, reliable repayment behavior, ideal for premium credit offers, low-interest loans, or pre-approved credit lines.
#
# Outlier risks exist in every segment:
# Even good scorers show some extreme outliers (up to 60 days), signaling that no group is risk-free. Individual case-level monitoring or behavioral analysis could help mitigate this.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps identify low-risk vs. high-risk customers.
# Supports decision-making on:
# Interest rate adjustments,
# Loan term structuring,
# Personalized offers for good scorers,
# Risk-mitigation strategies for poor scorers.
#
# Users with Poor credit scores and high delay variability can significantly increase default risk.
# Continuing to approve loans for this segment without intervention may result in increased NPAs (non-performing assets) and loss.
# Business should consider stricter policies, such as requiring co-signers or offering smaller, short-term credit to reduce exposure.

# %% [markdown]
# #### Chart - 13 Credit Score vs Loan Type (Grouped Bar), Category vs Category

# %%
# Chart - 13 visualization code
# Step 1: Identify loan-related columns
loan_cols = [col for col in df.columns if col.startswith('loan_')]

# Step 2: Melt the loan columns into long format
loan_data = df.melt(id_vars=['credit_score'], value_vars=loan_cols,
                    var_name='loan_type', value_name='has_loan')

# Step 3: Filter only loans taken
loan_data = loan_data[loan_data['has_loan'] == 1]

# Step 4: Clean loan_type labels
loan_data['loan_type'] = loan_data['loan_type'].str.replace('loan_', '', regex=False)\
                                               .str.replace('_loan', '', regex=False)\
                                               .str.replace('_', ' ')\
                                               .str.title()

# Step 5: Group by loan_type and credit_score and count
grouped = loan_data.groupby(['loan_type', 'credit_score']).size().reset_index(name='count')

# Step 6: Pivot for grouped bar plot
pivot_df = grouped.pivot(index='loan_type', columns='credit_score', values='count').fillna(0)

# Step 7: Plot grouped bar plot
ax = pivot_df.plot(kind='bar', figsize=(14,7), width=0.8, colormap='Set2')

plt.title('Count of Each Loan Type by Credit Score')
plt.xlabel('Loan Type')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Credit Score')
plt.grid(axis='y')

# Step 8: Add value labels on bars
for container in ax.containers:
    ax.bar_label(container, padding=3, fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Grouped bar plots are ideal to compare credit score distribution across loan types side by side, helping us identify which types of loans attract higher or lower credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive Observations:
# Consistent good credit users (~3.6k–3.9k) across all loans — especially strong in Student and Payday loans.
# Indicates a reliable low-risk segment present for all loan products.
#
# Risk Indicators:
# High number of poor credit users (~11.5k–11.9k) for every loan type.
# Highest in Payday, Credit Builder, and Mortgage — these may face higher default risks.
# Standard scores dominate (15k–16k), forming the bulk of borrowers — mixed risk, good for targeted improvement strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Guide targeted credit products: e.g., push Credit Builder Loans to Poor scorers.
# Improve risk assessment per loan type, aligning products with repayment capacity.
# Help banks identify loan types with best-performing (Good) scorers, ideal for premium products or cross-sell.
#
# High Poor credit usage in Payday and Personal Loans indicates higher default risk.
# Loan types with low Good credit penetration may need tighter risk control or adjusted terms (e.g., higher interest or collateral).

# %% [markdown]
# #### Chart - 14 KDE Plot of Monthly Inhand Salary by Credit Score, Category vs Numeric

# %%
plt.figure(figsize=(12,6))

# Plot each category manually to ensure proper labeling
colors = {'Poor': 'red', 'Standard': 'blue', 'Good': 'green'}
for category in df['credit_score'].unique():
    sns.kdeplot(
        data=df[df['credit_score'] == category],
        x='monthly_inhand_salary',
        fill=True,
        alpha=0.4,
        linewidth=2,
        label=category,
        color=colors[category]
    )

plt.title('KDE Plot of Monthly Inhand Salary by Credit Score')
plt.xlabel('Monthly Inhand Salary')
plt.ylabel('Density')
plt.grid(True)
plt.legend(title='Credit Score')
plt.tight_layout()
plt.show()

# Mean and median monthly inhand salary by credit score
summary_stats = df.groupby('credit_score')['monthly_inhand_salary'].agg(['mean', 'median']).round(2)
print(summary_stats)
# Out:
#                  mean   median
# credit_score
# Good          5399.92  3828.36
# Poor          3380.56  2672.09
# Standard      4239.44  3097.81

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# KDE (Kernel Density Estimate) shows the smooth distribution of monthly salaries across credit score groups.
#
# It helps uncover differences in income patterns among good, standard, and poor credit groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The KDE plot of monthly inhand salary across different credit score categories reveals a clear financial stratification. Individuals with good credit scores tend to have significantly higher monthly incomes, with an average of Rs.5,399.92 and a median of Rs.3,828.36. In contrast, those in the poor credit score category earn much less on average, with a mean income of Rs.3,380.56 and a median of Rs.2,672.09. The standard credit group falls in between, suggesting a transitional range in both salary and credit behavior. These patterns suggest that income plays a substantial role in determining creditworthiness, likely due to better repayment capacity and financial stability among higher earners. From a business perspective, this insight is valuable for designing credit risk models, offering tailored financial products, and segmenting customers based on earning potential. However, over-reliance on income alone could lead to biased decisions, potentially excluding responsible borrowers with lower incomes. Therefore, income should be used alongside behavioral metrics to ensure fair and inclusive credit evaluation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Guide targeted credit products: e.g., push Credit Builder Loans to Poor scorers.
# Improve risk assessment per loan type, aligning products with repayment capacity.
# Help banks identify loan types with best-performing (Good) scorers, ideal for premium products or cross-sell.
#
# High Poor credit usage in Payday and Personal Loans indicates higher default risk.
# Loan types with low Good credit penetration may need tighter risk control or adjusted terms (e.g., higher interest or collateral).

# %% [markdown]
# #### Chart - 15 Credit Scores vs Payment Behaviour(Cat plot), Category vs Category

# %%
# cat Pot visualization codel
plt.figure(figsize=(12,6))
custom_palette = {
    'Good': '#a8ddb5',      # Light green
    'Standard': '#9ecae1',  # Light blue
    'Poor': '#fcae91'       # Light red
}

sns.countplot(data=df, x='payment_behaviour', hue='credit_score', palette=custom_palette)

plt.title('Credit Score vs Payment Behaviour')
plt.xlabel('Payment Behaviour')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45)
plt.legend(title='Credit Score')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A cat plot (countplot) effectively reveals class distribution across categories.
#
# Payment behavior is a strong indicator of creditworthiness.
#
# It highlights whether certain risky behaviors like "Minimum Payment" or "Delayed Payment" are more common in Poor credit categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Poor credit holders might have a higher frequency of “Delayed” or “Minimum” payments.
#
# Good credit holders might mostly engage in “Full Payment” or timely payment behavior.
#
# Standard credit holders often show mixed behaviors—transition group.
#
# Skewed behavior counts help identify credit score vulnerability triggers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Lenders can design behavior-based credit risk scoring models.
#
# Helps tailor automated alerts or recommendations for financial discipline.
#
# Encourages targeted interventions (e.g., send reminders to users who regularly delay payments).
#
# Negative Growth Risk (if not addressed):
#
# If ignored, continued poor behavior may increase defaults.
#
# Failing to identify behavior trends in new applicants can impact loan portfolio quality.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# #### Chart - 16 Bubble Plot code (EMI vs Investment vs Income), Numeric vs Numeric vs Numeric (size/color)

# %%
plt.figure(figsize=(12, 7))

# Create scatterplot (Bubble plot)
bubble = sns.scatterplot(
    data=df,
    x='total_emi_per_month',
    y='amount_invested_monthly',
    hue='annual_income',
    size='num_credit_inquiries',
    sizes=(20, 300),
    palette='viridis',  # Good for continuous scale
    alpha=0.7,
    edgecolor='white',
    linewidth=0.5
)

# Set plot labels and title
plt.title('EMI vs Investment vs Income (Color = Income, Size = Inquiries)', fontsize=14)
plt.xlabel('Total EMI Per Month')
plt.ylabel('Amount Invested Monthly')

# Customize legend: move hue legend
h, l = bubble.get_legend_handles_labels()
bubble.legend(h[1:], l[1:], title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Bubble Plot was chosen because:
# It visualizes three numerical variables simultaneously:
# X-axis: EMI burden
# Y-axis: Monthly investment
# Color: Annual income level (continuous)
# Size: Number of credit inquiries
# This multidimensional view helps understand financial behavior patterns, useful for segmenting customers.
# Bubble size and color add extra insights beyond what a 2D scatterplot or bar plot can offer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Spending vs Investing Behavior:
# Many customers paying moderate EMIs are also making moderate investments.
# Few individuals are paying very high EMIs and investing heavily — mostly high-income (dark green).
# 2. High-Income Behavior:
# Darker-colored bubbles (high-income people) tend to be concentrated toward the upper-right, suggesting:
# High earners often both invest more and take higher EMIs.
# They also tend to have larger bubble sizes, suggesting frequent credit activity.
# 3. High Inquiries + Low Investment:
# Some large bubbles in the lower half (low investments) may represent:
# Customers with many credit inquiries, low investment, possibly credit-seeking or financially stressed.
# 4. Tradeoff Pattern:
# A mild negative relationship between EMI and investment is visible for lower-income groups (light-colored, low in y-axis).
# Suggests these people reduce investments when EMIs are high — indicating financial constraint.
# 5. Clusters:
# The chart may show distinct income groups forming visual bands based on color.
# You may notice clusters where:
# People with low EMI and low investment have low income and small credit inquiries.
# People with high EMI and high investment = high income and many inquiries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Product Targeting: Mid-to-high income groups with higher EMI and investments but moderate inquiries may be ideal for:
# Investment schemes.
# Low-risk credit expansion
#
# 2.  Profiling: Large bubbles in low EMI/investment areas indicate frequent inquiries with low financial engagement, a possible risk segment.
#
# 3. Cross-Sell Opportunity: Customers with high EMIs but low investments might need financial advisory or debt management products.
#
# Insights that lead to negative growth:
# Clusters of low-income customers with high credit inquiries but low EMI/investment may indicate:
#
# 1. High credit-seeking behavior but weak repayment capacity
#
# 2. Leads to loan defaults, customer churn, or bad debts
#
# Ignoring these patterns may cause:
#
# 1. Negative ROI on loans
#
# 2. Operational strain on collections

# %% [markdown]
# #### Chart - 17 Monthly Balance vs Age by Credit Score (Line Plot), Numeric vs Numeric with Category (hue)

# %%
# Step 1: Create age bins (5-year intervals from 15 to 70)
df['age_bin'] = pd.cut(df['age'], bins=range(15, 75, 5))

# Step 2: Group by age_bin and credit_score, then calculate average monthly balance
df_grouped = df.groupby(['age_bin', 'credit_score'])['monthly_balance'].mean().reset_index()

# Step 3: Convert age_bin to string for better x-axis formatting
df_grouped['age_bin'] = df_grouped['age_bin'].astype(str)

# Step 4: Plot the grouped data
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=df_grouped,
    x='age_bin',
    y='monthly_balance',
    hue='credit_score',
    palette='Set2',
    marker='o'
)

plt.title('Monthly Balance vs Age Group by Credit Score')
plt.xlabel('Age Group')
plt.ylabel('Average Monthly Balance')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-d143025bdf00>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df.groupby(['age_bin', 'credit_score'])['monthly_balance'].mean().reset_index()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line plot was chosen because:
#
# It clearly shows trends over ordered age groups (binned by 5-year intervals).
#
# It allows comparison between credit score categories in terms of how monthly balance evolves with age.
#
# Line plots are ideal for identifying growth or decline patterns across ordered categories like age.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Good Credit Score:
#
# Shows a consistently higher average monthly balance across almost all age bins.
#
# Indicates better financial management and disposable income.
#
# Peaks may occur around middle-age brackets (e.g., 35–50).
#
# 2. Standard Credit Score:
#
# Follows a moderate curve, generally below the good category.
#
# Can represent a transition segment—potential to move up with proper financial products.
#
# 3. Poor Credit Score:
#
# Monthly balances are consistently lower, indicating tighter cash flow.
#
# May remain flat or dip at certain age brackets, especially younger and older segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Age-wise targeting becomes possible:
#
# Younger customers with poor scores → promote budgeting tools or credit education.
#
# Older customers with standard scores → offer investment products.
#
# 2. Helps design age-segmented credit or savings plans based on disposable income patterns.
#
# Insights that indicate negative growth
# 1. Persistent low monthly balances in poor credit scores across all age bins may indicate:
#
# Long-term financial stress
#
# Low repayment capacity
#
# High risk segment if offered unsecured loans
#
# 2. Failing to filter out these patterns can lead to default risks and NPA buildup.

# %% [markdown]
# #### Chart - 18 Credit Cards vs Credit Utilization Ratio by Credit Score(Scatter Plot), Numeric vs Numeric with Category (hue)

# %%
# Ensure credit_score labels are consistently capitalized
df['credit_score'] = df['credit_score'].str.capitalize()

# Define a clear color palette for each category
custom_palette = {
    'Poor': 'red',
    'Standard': 'blue',
    'Good': 'green'
}

# Create the plot
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df,
    x='num_credit_card',
    y='credit_utilization_ratio',
    hue='credit_score',
    palette=custom_palette,
    alpha=0.6
)

plt.title('Credit Cards vs Utilization Ratio by Credit Score', fontsize=14)
plt.xlabel('Number of Credit Cards')
plt.ylabel('Credit Utilization Ratio (%)')
plt.grid(True)
plt.legend(title='Credit Score', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are ideal for exploring relationships between two continuous variables (here: number of credit cards and utilization ratio).
#
# Using hue='credit_score' helps visually separate categories and find trends per score group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. High Utilization Cluster: Users with a higher number of cards and high utilization often fall into the Poor score group (red dots).
#
# 2. Good Scores tend to cluster where the utilization is low, regardless of card count — indicating better financial behavior.
#
# 3. Standard Scores are spread in the mid-range — possible transition state.
#
# 4. Outliers with many cards and high utilization indicate risk, useful for identifying future defaulters.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Targeting financially responsible customers (green cluster with fewer cards & low utilization) allows:
#
# Safer loan approvals.
#
# Personalized offers for credit line increase or premium cards.
#
# Upselling investment or savings products.
#
# 2. Identifying mid-risk customers (blue cluster with moderate utilization) enables:
#
# Proactive nudges to reduce credit usage.
#
# Financial education offers or credit health tools.
#
# 3. Risk mitigation for high-utilization users (red cluster):
#
# Helps flag users for credit limit freezes or tighter scrutiny.
#
# Reduces default risk and improves overall portfolio quality.
#
#
#
# If ignored, some patterns can harm business:
#
# 1. Customers with many cards & high utilization ratios (top-right red cluster) may indicate:
#
# Over-reliance on credit.
#
# Risk of default or delinquency.
#
# 2. Extending new credit to these users without checks can lead to:
#
# Increased non-performing assets (NPAs).
#
# Losses on credit products, affecting profitability.

# %% [markdown]
# #### Chart - 19 Correlation Heatmap, Numeric vs Numeric (matrix)

# %%
# Correlation Heatmap visualization code
# Map credit_score to numeric
df['credit_score_numeric'] = df['credit_score'].map({'Poor': 0, 'Standard': 1, 'Good': 2})

# Define relevant numerical features
numerical_features = [
    'age', 'monthly_inhand_salary', 'num_bank_accounts', 'num_credit_card',
    'interest_rate', 'num_of_loan', 'delay_from_due_date',
    'num_of_delayed_payment', 'changed_credit_limit',
    'num_credit_inquiries', 'outstanding_debt', 'credit_utilization_ratio',
    'credit_history_age', 'total_emi_per_month', 'amount_invested_monthly',
    'monthly_balance', 'credit_score_numeric'
]

# Filter and compute correlation
df_numerical = df[numerical_features]
corr_matrix = df_numerical.corr()

# Plot heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm",
            annot_kws={"size": 8}, linewidths=0.5, linecolor='gray')
plt.title('Correlation Heatmap of Numerical Features', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Visual Simplicity:
# A heatmap shows pairwise correlations as a color-coded matrix — making it easy to spot strong and weak relationships at a glance.
#
# Quantifies Relationships:
# It uses correlation coefficients (from –1 to +1) to show how strongly variables move together:
# +1 → Strong positive relationship
# –1 → Strong negative relationship
# 0 → No relationship
#
# Multivariate Overview:
# Unlike scatter plots or box plots (which compare 2–3 variables), a heatmap can show all correlations among multiple features in one chart.
#
# Helps Feature Selection:
# Redundant features (high inter-correlation)
# Key drivers of a target variable (e.g., credit score)
# Negative influencers (e.g., overdue payments)
#
# Efficient Diagnosis:
# In financial or credit data, a heatmap helps analysts quickly diagnose potential causes for low scores, risky patterns, or potential biases.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive Correlations (Direct Relation with Credit Score):
# Monthly balance (+0.20) and amount invested monthly (+0.17) → Good indicators of financial discipline.
# Monthly in-hand salary (+0.21) → Higher income tends to support better credit scores.
# Credit history age (+0.39) → Longer history contributes positively to scoring.
# Negative Correlations (Inverse Relation):
# Number of delayed payments (-0.37) → Strongest negative factor.
# Delay from due date (-0.43) → Late repayments hurt creditworthiness.
# Credit utilization ratio (+0.05) → Overusing available credit lowers scores.
# Outstanding debt and interest rate (-0.39) → Higher debt burden reduces score reliability.

# %% [markdown]
# #### Chart - 20 Pair Plot, Numeric vs Numeric (multiple variables, with hue category)

# %%
# Pair Plot visualization code
# Ensure credit_score is categorical
df['credit_score'] = df['credit_score'].astype('category')

# Features for pairplot
pairplot_features = [
    'age', 'annual_income', 'monthly_inhand_salary',
    'num_credit_card', 'num_of_loan', 'delay_from_due_date',
    'credit_utilization_ratio', 'outstanding_debt', 'monthly_balance',
    'credit_score'
]

# Sample to improve performance
sample_df = df[pairplot_features].sample(n=1000, random_state=42)

# Limit Set2 palette to first 3 colors only
custom_palette = sns.color_palette("Set2")[:3]

# Plot
pair_plot = sns.pairplot(sample_df, hue='credit_score', diag_kind='hist',
                         palette=custom_palette, height=2.5, plot_kws={"alpha": 0.6})

# Move legend to top right
pair_plot._legend.set_bbox_to_anchor((1.05, 1))
pair_plot._legend.set_frame_on(True)
pair_plot._legend.set_title('Credit Score')

plt.suptitle('Pair Plot of Key Financial Variables', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Multivariate Relationships:
# It lets you explore how each pair of numeric features relate across different credit score categories (Good, Standard, Poor).
#
# Cluster Patterns by Category:
# Using hue='credit_score', it shows visual separation or overlap between groups — helpful for understanding how variables influence credit score classifications.
#
# Outlier Detection:
# Easily spot unusual data points that deviate from typical financial behavior.
#
# Distribution Insights:
# Diagonal plots (histograms) show the distribution of each variable, revealing skewness, spread, and modality.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Credit Utilization Ratio vs. Delay from Due Date:
# Poor credit score group tends to have higher utilization and more delays, indicating financial stress.
#
# Annual Income and Monthly In-Hand Salary:
# Good credit score individuals generally cluster in higher income ranges, showing better financial stability.
#
# Monthly Balance vs. Outstanding Debt:
# Individuals with Good scores often maintain positive monthly balances despite debt, suggesting responsible management.
#
# Number of Loans and Credit Cards:
# Poor score group has higher number of loans and credit cards, indicating potential over-reliance on credit.

# %% [markdown]
# #### Chart - 21 Heatmap of Loan Type vs Credit Score (Normalized %), Category vs Category (normalized frequency)

# %%
# Step 1: Select loan columns
loan_cols = [col for col in df.columns if col.startswith('loan_')]

# Step 2: Melt the DataFrame into long format
loan_data = df.melt(id_vars='credit_score', value_vars=loan_cols,
                    var_name='loan_type', value_name='has_loan')

# Step 3: Keep only rows where a loan exists
loan_data = loan_data[loan_data['has_loan'] == 1]

# Step 4: Clean the loan_type names
loan_data['loan_type'] = loan_data['loan_type'].str.replace('loan_', '').str.replace('_', ' ').str.title()

# Step 5: Count by loan type and credit score
grouped = loan_data.groupby(['loan_type', 'credit_score']).size().reset_index(name='count')

# Step 6: Pivot and normalize row-wise (%)
pivot = grouped.pivot(index='loan_type', columns='credit_score', values='count').fillna(0)
pivot_percent = pivot.div(pivot.sum(axis=1), axis=0) * 100  # normalize rows to percentages

# Step 7: Plot the heatmap
plt.figure(figsize=(12,7))
sns.heatmap(pivot_percent, annot=True, fmt=".1f", cmap='YlGnBu', linewidths=0.5, linecolor='gray')

plt.title('Normalized % of Credit Score by Loan Type')
plt.xlabel('Credit Score')
plt.ylabel('Loan Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps reveal pattern intensity across combinations.
#
# Normalizing by row (loan type) allows fair comparison even when raw loan counts differ.
#
# Useful to spot which credit score is overrepresented or underrepresented for each loan type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Standard credit scores dominate all loan types (~50% share).
#
# Poor scores are consistently high (≈37–38%) across loans — especially Auto and Student loans.
#
# Good scores are low across all loans (<13%), with Student loans having the lowest good-score ratio (12.5%).
#
# Personal and Debt Consolidation loans show slightly better credit score balance.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Based on the detailed EDA, Paisabazaar can achieve its business objectives by leveraging key patterns in customer financial behavior and demographics. Customers with good credit scores show lower utilization ratios, fewer inquiries, and better payment behavior—highlighting these as strong predictors for risk scoring models. Certain groups, such as students and payday loan users, are more likely to have poor scores, suggesting the need for targeted credit education and early intervention strategies.
#
# Higher-income individuals with strong investment patterns cluster in the good credit segment, presenting an opportunity for up-selling premium financial products. By using these insights, Paisabazaar can enhance customer segmentation, personalize offerings, reduce default risk, and improve overall customer engagement—all while maintaining ethical and inclusive lending practices.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This exploratory data analysis provided valuable insights into the financial behavior, demographic patterns, and risk factors associated with different credit score categories. Through a combination of univariate, bivariate, and multivariate analyses across 21 well-chosen visualizations, we identified key drivers of creditworthiness—such as timely payments, credit utilization, income levels, and loan behavior.
#
# Customers with Good credit scores consistently demonstrated low variability in delays, responsible credit card usage, fewer inquiries, and higher investment and income levels. Conversely, those with Poor credit scores often had higher delays, greater utilization ratios, and a stronger presence in high-risk loan types like payday or credit-builder loans.
#
# These findings enable Paisabazaar to:
#
# Enhance risk prediction models by prioritizing top predictors.
#
# Segment and personalize financial products based on user profiles.
#
# Target early interventions for high-risk segments (e.g., students, payday loan users).
#
# Drive business value by focusing on retention and up-selling to financially responsible customers.
#
# In summary, this EDA lays a strong analytical foundation for building accurate classification models, refining marketing strategies, and ultimately helping Paisabazaar improve credit outcomes for its users.
